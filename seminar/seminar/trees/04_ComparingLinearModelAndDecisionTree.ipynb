# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('HR.csv')

target = 'left'
class_names = ['stayed', 'left']
features = [c for c in data if c != target]
print(features)

X, y = data[features], data[target]
# Out:
# ['last_evaluation', 'number_project', 'average_montly_hours', 'time_spend_company', 'Work_accident', 'promotion_last_5years']

# %%
print("Logistic Regression:", cross_val_score(LogisticRegression(), X, y).mean())
# Out:
# Logistic Regression: 0.6287053143962126
# /home/mark/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/mark/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/mark/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/mark/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
print("Decision tree:", cross_val_score(DecisionTreeClassifier(), X, y).mean())
# Out:
# Decision tree: 0.6515762885910515
# /home/mark/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)

# %% [markdown]
# # Почему линейная модель хуже дерева?

# %%
data[:1]
# Out:
#    last_evaluation  number_project  average_montly_hours  time_spend_company  \
# 0             0.53               2                   157                   3
#
#    Work_accident  left  promotion_last_5years
# 0              0     1                      0

# %%
model = DecisionTreeClassifier()
model.fit(X, y)
pd.DataFrame({'features': features, 'importances': model.feature_importances_})
# Out:
#                 features  importances
# 0        last_evaluation     0.319590
# 1         number_project     0.150824
# 2   average_montly_hours     0.361833
# 3     time_spend_company     0.132905
# 4          Work_accident     0.027962
# 5  promotion_last_5years     0.006886

# %%
def plot_decision_surface(model, X, y):
    
    """Function to plot the decision boundaries of a classification model.
    
    Adopted from:
    http://scikit-learn.org/stable/auto_examples/ensemble/plot_voting_decision_regions.html
    http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_digits.html
    """

    plt.figure(figsize=(8,6))
    plt.subplot(1, 1, 1)

    n_classes = 2
    plot_step = 0.02
    plot_colors = ['white', 'tab:blue']
    cmap = plt.cm.Blues
    
    model.fit(X, y)

    d0, d1 = (X[:, 0].max() - X[:, 0].min()) * 0.1, (X[:, 1].max() - X[:, 1].min()) * 0.1
    x_min, x_max = X[:, 0].min() - d0, X[:, 0].max() + d0
    y_min, y_max = X[:, 1].min() - d1, X[:, 1].max() + d1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                         np.arange(y_min, y_max, plot_step))
    plt.tight_layout(h_pad=0.5, w_pad=0.5, pad=2.5)

    Z = model.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:,1]
    Z = Z.reshape(xx.shape)
    cs = plt.contourf(xx, yy, Z, cmap=cmap)

    plt.xlabel(c1)
    plt.ylabel(c2)

    # Plot the training points
    for i, color in zip(range(n_classes), plot_colors):
        idx = np.where(y == i)
        plt.scatter(X[idx, 0], X[idx, 1], cmap=cmap, label=class_names[i],
                    edgecolor='black', s=90, color=color)

    plt.suptitle("Decision surface of a decision tree using paired features")
    plt.legend(loc='lower right', borderpad=0, handletextpad=0)
    plt.axis("tight")
    
    plt.xlim(x_min, x_max)
    plt.ylim(y_min, y_max)
    
    return plt

# %%
c1, c2 = 'average_montly_hours', 'last_evaluation'

# %%
print("Decision tree:", cross_val_score(DecisionTreeClassifier(), X, y).mean())
plot_decision_surface(model = DecisionTreeClassifier(), X = data[[c1, c2]].values[::100], y = data[target][::100]);
# Out:
# /home/mark/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# Decision tree: 0.6524431686337268

# %%
print("Logistic Regression:", cross_val_score(LogisticRegression(), X, y).mean())
plot_decision_surface(model = LogisticRegression(), X = data[[c1, c2]].values[::100], y = data[target][::100]);
# Out:
# /home/mark/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/mark/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/mark/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/mark/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/mark/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic Regression: 0.6287053143962126

# %%
print("RandomForestClassifier:", cross_val_score(RandomForestClassifier(), X, y).mean())
plot_decision_surface(model = RandomForestClassifier(), X = data[[c1, c2]].values[::100], y = data[target][::100]);
# Out:
# /home/mark/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/mark/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/mark/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/mark/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier: 0.7205155031006202
# /home/mark/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
model = DecisionTreeClassifier()
model.fit(X, y)
tree_importances = model.feature_importances_

model = LogisticRegression()
model.fit(X, y)
linear_model_coef = model.coef_[0]

pd.DataFrame({'features': features, 'tree_importances': tree_importances, 'linear_model_coef': linear_model_coef})
# Out:
# /home/mark/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#                 features  tree_importances  linear_model_coef
# 0        last_evaluation          0.320686          -0.233852
# 1         number_project          0.151810          -0.021650
# 2   average_montly_hours          0.359947           0.001867
# 3     time_spend_company          0.132100           0.117117
# 4          Work_accident          0.028886          -0.574278
# 5  promotion_last_5years          0.006571          -0.538320

# %%
for c in data:
    print(c, ':', data[c].unique(), '\n')
# Out:
# last_evaluation : [0.53 0.86 0.88 0.87 0.52 0.5  0.77 0.85 1.   0.54 0.81 0.92 0.55 0.56
#  0.47 0.99 0.51 0.89 0.83 0.95 0.57 0.49 0.46 0.62 0.94 0.48 0.8  0.74
#  0.7  0.78 0.91 0.93 0.98 0.97 0.79 0.59 0.84 0.45 0.96 0.68 0.82 0.9
#  0.71 0.6  0.65 0.58 0.72 0.67 0.75 0.73 0.63 0.61 0.76 0.66 0.69 0.37
#  0.64 0.39 0.41 0.43 0.44 0.36 0.38 0.4  0.42]
#
# number_project : [2 5 7 6 4 3]
#
# average_montly_hours : [157 262 272 223 159 153 247 259 224 142 135 305 234 148 137 143 160 255
#  282 147 304 139 158 242 239 128 132 294 134 145 140 246 126 306 152 269
#  127 281 276 182 273 307 309 225 226 308 244 286 161 264 277 275 149 295
#  151 249 291 232 130 129 155 265 279 284 221 154 150 267 257 177 144 289
#  258 263 251 133 216 300 138 260 183 250 292 283 245 256 278 240 136 301
#  243 296 274 164 146 261 285 141 297 156 287 219 254 228 131 252 236 270
#  298 192 248 266 238 229 233 268 231 253 302 271 290 235 293 241 218 199
#  180 195 237 227 172 206 181 217 310 214 198 211 222 213 202 184 204 288
#  220 299 303 212 196 179 205 230 203 280 169 188 178 175 166 163 168 165
#  189 162 215 193 176 191 174 201 208 171 111 104 106 100 194 209 185 200
#  207 187 210 186 167 108 122 110 115 197 102 109 190  99 101  97 173 121
#  170 105 118 119 117 114  96  98 107 123 116 125 113 120 112 124 103]
#
# time_spend_company : [ 3  6  4  5  2  8 10  7]
#
# Work_accident : [0 1]
#
# left : [1 0]
#
# promotion_last_5years : [0 1]
